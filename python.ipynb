# %% [markdown]
# Print Hello World

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# print string value and integer

# %%
print("Hello World",4+5)
# Out:
# Hello World 9

# %% [markdown]
# comments

# %%
#This is a COMMENT

# %% [markdown]
# Multiple Line Comment

# %%
'''This is a comment
written in 
more than just one line'''
# Out:
# 'This is a comment\nwritten in \nmore than just one line'

# %% [markdown]
# print arthematic functions

# %%
print(45+98,65-21,45/5,67*9)
# Out:
# 143 44 9.0 603

# %% [markdown]
# print sum of two number

# %%
print(45+98)
# Out:
# 143

# %% [markdown]
# print subtraction

# %%
print(65-21)
# Out:
# 44

# %% [markdown]
# print Multiplication

# %%
print(67*9)
# Out:
# 603

# %% [markdown]
# Print Divion

# %%
print(30/5)
# Out:
# 6.0

# %% [markdown]
# Declare variable

# %%
X = "Hello world"
print(X)
# Out:
# Hello world

# %% [markdown]
# declare integers

# %%
number = 5,7,9,10
print(number)
# Out:
# (5, 7, 9, 10)

# %% [markdown]
# assign values to multiple variables in one line

# %%
x,y,z= "apple","banana","mango"
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# mango

# %% [markdown]
# syntax to add the value to 3 variables in one statement

# %%
x = y = z = 'Hello Python'
print(x,y,z)
# Out:
# Hello Python Hello Python Hello Python

# %% [markdown]
# declare varibles and addition

# %%
a = 87
b = 45
print(a + b)
# Out:
# 132
