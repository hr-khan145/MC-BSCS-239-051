# %% [markdown]
# Comments

# %%
# This is a comment

# %% [markdown]
# Multi-line Comments

# %%
""" Triple Quotes 
used for 
multi-line
comments"""
# Out:
# ' Triple Quotes \nused for \nmulti-line\ncomments'

# %% [markdown]
# Declare Variables for integer Datatype

# %%
a=80
print(a)
b=90
print(b)
c=1440
print(c)
# Out:
# 80
# 90
# 1440

# %% [markdown]
# Python Boleans

# %%
print(78==90)
# Out:
# False

# %%
print(130!=24)
# Out:
# True

# %%
print(35>27)
# Out:
# True

# %%
print(28<45)
# Out:
# True

# %%
print(45<= 98)
# Out:
# True

# %%
print(25>= 48)
# Out:
# False

# %% [markdown]
# Input operator

# %%
name =input("Enter your name")
print("My name is",name)
# Out:
# My name is Hassan Raza

# %% [markdown]
# Integer type input from USER

# %%
age=int(input("What is your age"))
print("My age is",age)
# Out:
# My age is 23

# %% [markdown]
# Take any Input Value from user

# %%
x=int(input("Enter a number:"))
print("Your Answer is",x)
# Out:
# Your Answer is 52

# %% [markdown]
# Assigning Both tpes of quotes

# %%
print("I think,'Python is Powerfull'")
# Out:
# I think,'Python is Powerfull'

# %%
print('He said,"Coding is life"')
# Out:
# He said,"Coding is life"
